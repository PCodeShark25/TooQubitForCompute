# %%
import qiskit_metal as qm

# %%
from qiskit_metal import designs, draw, MetalGUI, Dict, open_docs
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.qubits.transmon_pocket_6 import TransmonPocket6
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.framed_path import RouteFramed
from qiskit_metal.qlibrary.tlines.mixed_path import RouteMixed
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
import numpy as np
from collections import OrderedDict

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

# %%
design.chips.main
# Out:
# {'material': 'silicon',
#  'layer_start': '0',
#  'layer_end': '2048',
#  'size': {'center_x': '0.0mm',
#   'center_y': '0.0mm',
#   'center_z': '0.0mm',
#   'size_x': '9mm',
#   'size_y': '6mm',
#   'size_z': '-750um',
#   'sample_holder_top': '890um',
#   'sample_holder_bottom': '1650um'}}

# %%
def ChipSize(x:str, y:str, cheese: bool = False, layer: int = 0):
    design.chips.main.size.size_x = x
    design.chips.main.size.size_y = y
    design.chips.default_settings['cheese'] = cheese
    design.chips.default_settings['layer_start'] = layer

# %%
ChipSize('11mm', '11mm', False, 0)

# %%
def guidraw(n=1, dlt=False, hlt=False):
    if dlt:
        gui.rebuild()
        gui.screenshot()
    else:
        gui.rebuild()
        gui.autoscale()
        all_component_names = design.components.keys()
        #if n==1:
            #gui.edit_component(['Q1'])
        gui.zoom_on_components(all_component_names)
        if hlt:
            all_component_names = design.components.keys()
            gui.highlight_components(all_component_names)
        gui.screenshot()

# %%
def clean():
    design.delete_all_components()

# %%
def QTreeN(n,a=6):
    qudict = Dict()
    offset = 125
    design.overwrite_enabled = True
    options = Dict(
        pad_width = '450um',
        pocket_width = '650um',
        connection_pads = Dict(
            ip = Dict(loc_W= +0, loc_H = -1, pad_width = '90um'),
            left = Dict(loc_W= -1, loc_H = +1, pad_width = '90um'),
            right = Dict(loc_W= +1, loc_H = +1, pad_width = '90um')
        ),
    layer = 0
    )
    for i in range(n):
        posX = 
        posY = 
        angle =
        qudict[f'q{i}'] = TransmonPocket6(design, f'Q{i}', options=Dict(pos_x=posX,pos_y=posY, orientation = angle, **options))
    #q2 = TransmonPocket6(design, 'Q2', options=Dict(pos_x= str(a/2)+'0mm',pos_y=offset, orientation = -90, **options))
    #q3 = TransmonPocket6(design, 'Q3', options=Dict(pos_x= str(-a/2)+'0mm',pos_y=offset, orientation = 90, **options))
    guidraw(n=n, hlt=True)
# Out:
#   Cell In[9], line 16
#     posX =
#            ^
# SyntaxError: invalid syntax

# %%
QTree3()

# %%
clean()

# %%
def connections(total_length:str, com1:str, pin1:str, com2: str, pin2: str, st_st:str, end_st: str, asym):
    ops = Dict(fillet = '99.99um')
    myopts= Dict(
        total_length = total_length,
        hfss_wire_bonds = True,
        pin_inputs = Dict(
            start_pin = Dict(
                component = com1,
                pin = pin1
            ),
            end_pin = Dict(
                component = com2,
                pin = pin2
            )
        ),
        lead = Dict(
            start_straight = st_st,
            end_straight = end_st
        ),
        meander = Dict(
            #spacing = spacing,
            asymmetry = asym
        ),
        layer = 0,
        **ops
    )

    try: 
        cpw.delete()
    except NameError: pass

    cpw = RouteMeander(design, options=myopts)

# %%
n = 5

# %%
def rudimentree(n):
    a=6
    k = 0.5
    offset = 0.125
    design.overwrite_enabled = True
    options = Dict(
        pad_width = '450um',
        pocket_width = '650um',
        connection_pads = Dict(
            ip = Dict(loc_W= +0, loc_H = -1, pad_width = '90um'),
            left = Dict(loc_W= -1, loc_H = +1, pad_width = '90um'),
            right = Dict(loc_W= +1, loc_H = +1, pad_width = '90um')
        ),
        layer = 0
    )
    if n>=1:
        q1 = TransmonPocket6(design, 'Q1', options=Dict(pos_x='+0.00mm',pos_y='0mm', orientation = 0, **options))

    if n>=2:
    #first branch
        q2 = TransmonPocket6(design, 'Q2', options=Dict(pos_x= str(k*a)+'0mm',pos_y= str(offset) + 'mm', orientation = -90, **options))
    if n>=3:
        q3 = TransmonPocket6(design, 'Q3', options=Dict(pos_x= str(-k*a)+'0mm',pos_y= str(offset) + 'mm', orientation = 90, **options))
    #second branch
    if n>=4:
        q4 = TransmonPocket6(design, 'Q4', options=Dict(pos_x= str(-k*a-offset)+'0mm',pos_y=str(k**2*a) + '0mm', orientation = 0, **options))
    if n>=5:
        q6 = TransmonPocket6(design, 'Q5', options=Dict(pos_x= str(k*a+offset)+'0mm',pos_y=str(k**2*a) + '0mm', orientation = 0, **options))
    if n>=6:
        q5 = TransmonPocket6(design, 'Q6', options=Dict(pos_x= str(-k*a-offset)+'0mm',pos_y=str(-k**2*a) + '0mm', orientation = 90*2, **options))
    if n>=7:
        q7 = TransmonPocket6(design, 'Q7', options=Dict(pos_x= str(k*a+offset)+'0mm',pos_y=str(-k**2*a) + '0mm', orientation = 90*2, **options))
    guidraw(n=7, hlt=True)

# %%
rudimentree(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 rudimentree(n)
#
# NameError: name 'n' is not defined

# %%
jogsS = OrderedDict()
jogsE = OrderedDict()
ops = Dict(fillet = '90um')

jogl = '200um'  
for i in range(10):
    if i==0:
        jogsS[i] = ['L', jogl]
    elif i%4==1:
        jogsS[i] = ['L', jogl]
        jogsS[i+1] = ['R', jogl]
    elif i%4==3:
        jogsS[i] = ['R', jogl]
        jogsS[i+1] = ['L', jogl]

for i in range(10):
    if i==0:
        jogsE[i] = ['R', jogl]
    elif i%4==1:
        jogsE[i] = ['R', jogl]
        jogsE[i+1] = ['L', jogl]
    elif i%4==3:
        jogsE[i] = ['L', jogl]
        jogsE[i+1] = ['R', jogl]
        
options = Dict(
    total_length = '9mm',
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'Q1',
            pin = 'right'
        ),
        end_pin = Dict(
            component = 'Q2',
            pin = 'ip'
        )
    ),
    lead = Dict(
        start_straight = '0.1mm',
        end_straight = '0.0mm',
        #start_jogged_extension = jogsS,
        #end_jogged_extension = jogsE
    ),
    meander = Dict(
        spacing = '200um',
        asymmetry = '-0.5um'
    ),
    layer = 0,
    **ops
)

try:
    cpw23.delete()
except NameError: pass

cpw23  = RouteMeander(design, options=options)

guidraw(n=3)
# Out:
# 12:07PM 38s WARNING [__init__]: Component Q1 does not exist. None has not been built. Please check your pin_input values.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 58
#      54 except NameError: pass
#      56 cpw23  = RouteMeander(design, options=options)
# ---> 58 guidraw(n=3)
#
# Cell In[7], line 11, in guidraw(n, dlt, hlt)
#       8 all_component_names = design.components.keys()
#       9 #if n==1:
#      10     #gui.edit_component(['Q1'])
# ---> 11 gui.zoom_on_components(all_component_names)
#      12 if hlt:
#      13     all_component_names = design.components.keys()
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\qiskit_metal\_gui\main_window.py:785, in MetalGUI.zoom_on_components(self, components)
#     779 """Zoom to the components.
#     780
#     781 Args:
#     782     components (List[str]): List of components to zoom to
#     783 """
#     784 bounds = self.canvas.find_component_bounds(components)
# --> 785 self.canvas.zoom_to_rectangle(bounds)
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\qiskit_metal\renderers\renderer_mpl\mpl_canvas.py:637, in PlotCanvas.zoom_to_rectangle(self, bounds, ax)
#     635 if ax is None:
#     636     for ax in self.axes:
# --> 637         self.zoom_to_rectangle(bounds, ax)
#     638 else:
#     639     ax.set_xlim(bounds[0], bounds[2])
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\qiskit_metal\renderers\renderer_mpl\mpl_canvas.py:639, in PlotCanvas.zoom_to_rectangle(self, bounds, ax)
#     637         self.zoom_to_rectangle(bounds, ax)
#     638 else:
# --> 639     ax.set_xlim(bounds[0], bounds[2])
#     640     ax.set_ylim(bounds[1], bounds[3])
#     641     # ax.redraw_in_frame()
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\matplotlib\axes\_base.py:3711, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3709         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3710     right = xmax
# -> 3711 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\matplotlib\axis.py:1235, in Axis._set_lim(self, v0, v1, emit, auto)
#    1232 name = self._get_axis_name()
#    1234 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1235 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1236 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1238 if v0 is None or v1 is None:
#    1239     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1240     # so only grab the limits if we really need them.
#
# File ~\anaconda3\envs\quskitmental\lib\site-packages\matplotlib\axes\_base.py:3632, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3629     converted_limit = converted_limit.squeeze()
#    3630 if (isinstance(converted_limit, Real)
#    3631         and not np.isfinite(converted_limit)):
# -> 3632     raise ValueError("Axis limits cannot be NaN or Inf")
#    3633 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
jogsS = OrderedDict()
jogsE = OrderedDict()
ops = Dict(fillet = '90um')

jogl = '200um'  
for i in range(10):
    if i==0:
        jogsS[i] = ['L', jogl]
    elif i%4==1:
        jogsS[i] = ['L', jogl]
        jogsS[i+1] = ['R', jogl]
    elif i%4==3:
        jogsS[i] = ['R', jogl]
        jogsS[i+1] = ['L', jogl]

for i in range(10):
    if i==0:
        jogsE[i] = ['R', jogl]
    elif i%4==1:
        jogsE[i] = ['R', jogl]
        jogsE[i+1] = ['L', jogl]
    elif i%4==3:
        jogsE[i] = ['L', jogl]
        jogsE[i+1] = ['R', jogl]


options = Dict(
    total_length = '9mm',
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'Q1',
            pin = 'left'
        ),
        end_pin = Dict(
            component = 'Q3',
            pin = 'ip'
        )
    ),
    lead = Dict(
        start_straight = '0.1mm',
        end_straight = '0.0mm',
        #start_jogged_extension = jogsS,
        #end_jogged_extension = jogsE
    ),
    meander = Dict(
        spacing = '200um',
        asymmetry = '+0.5um'
    ),
    layer = 0,
    **ops
)

try:
    cpw13.delete()
except NameError: pass

cpw13 = RouteMeander(design, options=options)

guidraw(n=3)

# %%
options = Dict(
    total_length = '3mm',
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'Q2',
            pin = 'left'
        ),
        end_pin = Dict(
            component = 'Q6',
            pin = 'ip'
        )
    ),
    lead = Dict(
        start_straight = '0.1mm',
        end_straight = '0.0mm',
        #start_jogged_extension = jogsS,
        #end_jogged_extension = jogsE
    ),
    meander = Dict(
        spacing = '200um',
        asymmetry = '+0.5um'
    ),
    layer = 0,
    **ops
)

try:
    cpw33.delete()
except NameError: pass

cpw33 = RoutePathfinder(design, options=options)

guidraw(n=3)

# %%
def rudimentconn(n):
    ops = Dict(fillet = '90um')
    if n>=2:
        options = Dict(
            total_length = '6mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q1',
                    pin = 'right'
                ),
                end_pin = Dict(
                    component = 'Q2',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '200um',
                asymmetry = '+0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw12.delete()
        except NameError: pass
        cpw12  = RouteMeander(design, options=options)
    
    if n>=3:
        options = Dict(
            total_length = '6mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q1',
                    pin = 'left'
                ),
                end_pin = Dict(
                    component = 'Q3',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '200um',
                asymmetry = '+0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw13.delete()
        except NameError: pass
        cpw13  = RouteMeander(design, options=options)
        
    if n>=4:
        options = Dict(
            total_length = '3mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q2',
                    pin = 'left'
                ),
                end_pin = Dict(
                    component = 'Q5',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '150um',
                asymmetry = '-0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw25.delete()
        except NameError: pass
        cpw25  = RouteMeander(design, options=options)
    if n>=5:
        options = Dict(
            total_length = '3mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q3',
                    pin = 'right'
                ),
                end_pin = Dict(
                    component = 'Q4',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '200um',
                asymmetry = '+0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw34.delete()
        except NameError: pass
        cpw34  = RouteMeander(design, options=options)
    
    if n>=6:
        options = Dict(
            total_length = '3mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q2',
                    pin = 'right'
                ),
                end_pin = Dict(
                    component = 'Q6',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '200um',
                asymmetry = '+0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw26.delete()
        except NameError: pass
        cpw25  = RouteMeander(design, options=options)
    
    if n>=7:
        options = Dict(
            total_length = '3mm',
            pin_inputs = Dict(
                start_pin = Dict(
                    component = 'Q3',
                    pin = 'left'
                ),
                end_pin = Dict(
                    component = 'Q7',
                    pin = 'ip'
                )
            ),
            lead = Dict(
                start_straight = '0.1mm',
                end_straight = '0.0mm',
                #start_jogged_extension = jogsS,
                #end_jogged_extension = jogsE
            ),
            meander = Dict(
                spacing = '200um',
                asymmetry = '+0.5um'
            ),
            layer = 0,
            **ops
        )
        try:
            cpw37.delete()
        except NameError: pass
        cpw37  = RouteMeander(design, options=options)
    guidraw(n=3)

# %%
n=5
rudimentree(n)
rudimentconn(n)
# Out:
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 25 and pin: right are already in net_info with net_id 53
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 25, right, 12, start and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 26 and pin: ip are already in net_info with net_id 54
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 26, ip, 12, end and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 25 and pin: left are already in net_info with net_id 55
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 25, left, 13, start and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 27 and pin: ip are already in net_info with net_id 56
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 27, ip, 13, end and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 25 and pin: right are already in net_info with net_id 53
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 25, right, 21, start and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 26 and pin: ip are already in net_info with net_id 54
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 26, ip, 21, end and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 25 and pin: left are already in net_info with net_id 55
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 25, left, 22, start and will not be added to components.
# 12:11PM 00s WARNING [add_pins_to_table]: Component: 27 and pin: ip are already in net_info with net_id 56
# 12:11PM 00s WARNING [connect_pins]: NetId was not added for 27, ip, 22, end and will not be added to components.
# 12:11PM 01s WARNING [add_pins_to_table]: Component: 26 and pin: left are already in net_info with net_id 57
# 12:11PM 01s WARNING [connect_pins]: NetId was not added for 26, left, 23, start and will not be added to components.
# 12:11PM 01s WARNING [add_pins_to_table]: Component: 29 and pin: ip are already in net_info with net_id 58
# 12:11PM 01s WARNING [connect_pins]: NetId was not added for 29, ip, 23, end and will not be added to components.
# 12:11PM 01s WARNING [check_lengths]: For path table, component=cpw_9, key=trace has short segments that could cause issues with fillet. Values in (1-5)  are index(es) in shapely geometry.
# 12:11PM 01s WARNING [check_lengths]: For path table, component=cpw_9, key=cut has short segments that could cause issues with fillet. Values in (1-5)  are index(es) in shapely geometry.
# 12:11PM 01s WARNING [add_pins_to_table]: Component: 27 and pin: right are already in net_info with net_id 59
# 12:11PM 01s WARNING [connect_pins]: NetId was not added for 27, right, 24, start and will not be added to components.
# 12:11PM 01s WARNING [add_pins_to_table]: Component: 28 and pin: ip are already in net_info with net_id 60
# 12:11PM 01s WARNING [connect_pins]: NetId was not added for 28, ip, 24, end and will not be added to components.
# 12:11PM 05s WARNING [check_lengths]: For path table, component=cpw_13, key=trace has short segments that could cause issues with fillet. Values in (2-3)  are index(es) in shapely geometry.
# 12:11PM 05s WARNING [check_lengths]: For path table, component=cpw_13, key=cut has short segments that could cause issues with fillet. Values in (2-3)  are index(es) in shapely geometry.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 25 and pin: right are already in net_info with net_id 61
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 25, right, 5, start and will not be added to components.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 26 and pin: ip are already in net_info with net_id 62
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 26, ip, 5, end and will not be added to components.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 25 and pin: left are already in net_info with net_id 63
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 25, left, 6, start and will not be added to components.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 27 and pin: ip are already in net_info with net_id 64
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 27, ip, 6, end and will not be added to components.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 25 and pin: right are already in net_info with net_id 61
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 25, right, 12, start and will not be added to components.
# 12:11PM 05s WARNING [add_pins_to_table]: Component: 26 and pin: ip are already in net_info with net_id 62
# 12:11PM 05s WARNING [connect_pins]: NetId was not added for 26, ip, 12, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 25 and pin: left are already in net_info with net_id 63
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 25, left, 13, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 27 and pin: ip are already in net_info with net_id 64
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 27, ip, 13, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 26 and pin: left are already in net_info with net_id 65
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 26, left, 14, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 29 and pin: ip are already in net_info with net_id 66
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 29, ip, 14, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 27 and pin: right are already in net_info with net_id 67
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 27, right, 15, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 28 and pin: ip are already in net_info with net_id 68
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 28, ip, 15, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 25 and pin: right are already in net_info with net_id 61
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 25, right, 21, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 26 and pin: ip are already in net_info with net_id 62
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 26, ip, 21, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 25 and pin: left are already in net_info with net_id 63
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 25, left, 22, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 27 and pin: ip are already in net_info with net_id 64
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 27, ip, 22, end and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 26 and pin: left are already in net_info with net_id 65
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 26, left, 23, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 29 and pin: ip are already in net_info with net_id 66
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 29, ip, 23, end and will not be added to components.
# 12:11PM 06s WARNING [check_lengths]: For path table, component=cpw_9, key=trace has short segments that could cause issues with fillet. Values in (1-5)  are index(es) in shapely geometry.
# 12:11PM 06s WARNING [check_lengths]: For path table, component=cpw_9, key=cut has short segments that could cause issues with fillet. Values in (1-5)  are index(es) in shapely geometry.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 27 and pin: right are already in net_info with net_id 67
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 27, right, 24, start and will not be added to components.
# 12:11PM 06s WARNING [add_pins_to_table]: Component: 28 and pin: ip are already in net_info with net_id 68
# 12:11PM 06s WARNING [connect_pins]: NetId was not added for 28, ip, 24, end and will not be added to components.
# 12:11PM 08s WARNING [check_lengths]: For path table, component=cpw_13, key=trace has short segments that could cause issues with fillet. Values in (2-3)  are index(es) in shapely geometry.
# 12:11PM 08s WARNING [check_lengths]: For path table, component=cpw_13, key=cut has short segments that could cause issues with fillet. Values in (2-3)  are index(es) in shapely geometry.
